# %%
import os
import requests
from dotenv import load_dotenv
import json

# Laad je .env bestand
load_dotenv()

# Haal de endpoints en token op
RELATIES_URL = os.getenv('ASSUPORTAL_RELATIES')
CONTRACTEN_URL = os.getenv('ASSUPORTAL_CONTRACTEN')
BEARER_TOKEN = os.getenv('ASSUPORTAL_API_TOKEN')  # Of hoe je het token ook genoemd hebt

GRIP_ENDPOINT = os.getenv('GRIP_ENDPOINT')
GRIP_BEARER_TOKEN = os.getenv('GRIP_BEARER_TOKEN')

print(f"e-grip Endpoint: {GRIP_ENDPOINT}")
print(f"Token aanwezig: {'Ja' if GRIP_BEARER_TOKEN else 'Nee'}")

print(f"Relaties URL: {RELATIES_URL}")
print(f"Contracten URL: {CONTRACTEN_URL}")
print(f"Token aanwezig: {'Ja' if BEARER_TOKEN else 'Nee'}")
# Out:
# e-grip Endpoint: None
# Token aanwezig: Nee
# Relaties URL: https://secure-app1.assuportal.nl/joho/api/?q=api/relaties
# Contracten URL: https://secure-app1.assuportal.nl/joho/api/?q=api/contracten
# Token aanwezig: Ja

# %%
form_id = 2  # Start with the example ID from the email

grip_headers = {
    'Authorization': f'Bearer {GRIP_BEARER_TOKEN}'
}

try:
    print(f"Making API call to e-grip for formId={form_id}...")
    response_grip = requests.get(
        f"{GRIP_ENDPOINT}?formId={form_id}",
        headers=grip_headers,
        timeout=30
    )

    response_grip.raise_for_status()

    print(f"✓ Success! Status code: {response_grip.status_code}")

    data_grip = response_grip.json()

    print("\n--- Complete JSON Response ---")
    print(json.dumps(data_grip, indent=2, ensure_ascii=False))

except requests.exceptions.RequestException as e:
    print(f"✗ Error: {e}")
    if hasattr(e, 'response') and e.response is not None:
        print(f"Response text: {e.response.text}")
# Out:
# Making API call to e-grip for formId=2...
# ✓ Success! Status code: 200
#
# --- Complete JSON Response ---
# {
#   "formId": "2",
#   "fields": [
#     {
#       "position": 10,
#       "title": "Expat- en Emigratieadvies"
#     },
#     {
#       "position": 20,
#       "title": "Ik vraag verzekeringsadvies voor mezelf aan"
#     },
#     {
#       "position": 30,
#       "title": "Wat is uw naam en e-mailadres, en wat is uw relatie tot de persoon die verzekeringsadvies nodig heeft? Let op! Vul in het formulier wel de gegevens in van de te verzekeren persoon / personen."
#     },
#     {
#       "position": 40,
#       "title": "Persoonlijke gegevens van de hoofdverzekerde"
#     },
#     {
#       "position": 50,
#       "title": "Aanhef"
#     },
#     {
#       "position": 60,
#       "title": "Voorletters en roepnaam"
#     },
#     {
#       "position": 70,
#       "title": "Achternaam"
#     },
#     {
#       "position": 80,
#       "title": "Geboortedatum"
#     },
#     {
# ...

# %%
# Configureer de headers met je Bearer token
headers = {
    'Authorization': f'Bearer {BEARER_TOKEN}',
    'Content-Type': 'application/json'
}

# Configureer pagination parameters (start met een kleine page size voor testen)
params = {
    'page': 10,
    'size': 10  # Klein aantal voor eerste test
}

# %%
detail = RELATIES_URL + "/" + str(10690)

# %%
# Maak de API call naar het Relaties endpoint
try:
    print("Making API call to Relaties endpoint...")
    response_relaties = requests.get("https://secure-app1.assuportal.nl/joho/api/?q=api/relaties&filter[datum_van]=2025-11-01&filter[datum_tot]=2026-01-12", headers=headers, params=params, timeout=30)

    # Check of de request succesvol was
    response_relaties.raise_for_status()

    print(f"✓ Success! Status code: {response_relaties.status_code}")

    # Parse de JSON response
    data_relaties = response_relaties.json()

    # Print de volledige response (mooi geformatteerd)
    print("\n--- Complete JSON Response ---")
    print(json.dumps(data_relaties, indent=2, ensure_ascii=False))
except requests.exceptions.RequestException as e:
    print(f"✗ Error: {e}")
    if hasattr(e.response, 'text'):
        print(f"Response text: {e.response.text}")
# Out:
# Making API call to Relaties endpoint...
# ✓ Success! Status code: 200
#
# --- Complete JSON Response ---
# {
#   "result": "ok",
#   "data": [
#     {
#       "id": 15188,
#       "ts_aangemaakt": "2018-11-26 12:17:09",
#       "kenmerk": null,
#       "type": "Persoon",
#       "naam": "Maas, J. (Jan) de vader van Jelke Maas (verzekerde)",
#       "adn_postbusnummer": "",
#       "standaard_email": "maas.snoeck@gmail.com",
#       "standaard_email_nieuwsbrief": "1",
#       "standaard_correspondent": {
#         "id": 13562,
#         "naam": "Jelke Maas",
#         "achternaam": "Maas",
#         "voornaam": "Jelke",
#         "tussenvoegsels": "",
#         "geslacht": "M",
#         "initialen": "J."
#       }
#     },
#     {
#       "id": 17683,
#       "ts_aangemaakt": "2023-02-01 13:35:50",
#       "kenmerk": null,
#       "type": "Familie",
#       "naam": "Maercke, M.L.A.  (Mathias) van",
#       "adn_postbusnummer": "",
# ...

# %%
detail_cont = CONTRACTEN_URL + "/" +str(1234)

# %%
# Maak de API call naar het Relaties endpoint
try:
    print("Making API call to Relaties endpoint...")
    response_relaties = requests.get("https://secure-app1.assuportal.nl/joho/api/?q=api/contracten&filter[datum_van]=2025-11-11&filter[datum_tot]=2025-11-12", headers=headers, params=params, timeout=30)

    # Check of de request succesvol was
    response_relaties.raise_for_status()

    print(f"✓ Success! Status code: {response_relaties.status_code}")

    # Parse de JSON response
    data_relaties = response_relaties.json()

    # Print de volledige response (mooi geformatteerd)
    print("\n--- Complete JSON Response ---")
    print(json.dumps(data_relaties, indent=2, ensure_ascii=False))
except requests.exceptions.RequestException as e:
    print(f"✗ Error: {e}")
    if hasattr(e.response, 'text'):
        print(f"Response text: {e.response.text}")
# Out:
# Making API call to Relaties endpoint...
# ✓ Success! Status code: 200
#
# --- Complete JSON Response ---
# {
#   "result": "ok",
#   "data": [
#     {
#       "id": 12643,
#       "type": "standaard",
#       "relatie_id": 18911,
#       "ts_aangemaakt": "2025-11-12 15:29:39",
#       "ts_gewijzigd": "2025-12-23 09:41:10",
#       "polisnummer": "274639",
#       "status": "Actief",
#       "omschrijving": "1-Goudse Expat Pakket",
#       "omschrijving_verstrekker": "",
#       "datum_verval": "0000-00-00",
#       "datum_expiratie": "0000-00-00",
#       "datum_prolongatie": "0000-00-00",
#       "betaaltermijn": 1,
#       "opzegtermijn": null,
#       "relatie_naam": "Helden, J. (Johanna) van"
#     },
#     {
#       "id": 12731,
#       "type": "standaard",
#       "relatie_id": 18977,
#       "ts_aangemaakt": "2025-12-29 12:05:56",
#       "ts_gewijzigd": "2026-01-03 12:22:49",
#       "polisnummer": "275289",
#       "status": "Actief",
# ...
