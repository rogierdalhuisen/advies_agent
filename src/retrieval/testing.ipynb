# %%
from retriever import retriever
from reranker.reranker import reranker

# %%
#etriever = InsuranceRetriever()
k = 15
query = "welke dekkingniveaus vergoeden medicijnen en wat is de maximale vergoeding. Vergelijk verzkeringen en dekkingniveaus"

# %%
results = retriever.retrieve_company_docs(query=query, insurance_provider="allianz_care", k=k)
docs, scores = zip(*results)

print("Retrieved Documents:")
for idx, (doc, score) in enumerate(results):
    print(f"{idx + 1}. Score: {score} \n {doc.page_content} \n \n")  # Print first 100 characters
# Out:
# Retrieved Documents:
# 1. Score: 0.5
#  # How to use your cover
# ## Terms and conditions of your cover
# ### Definitions
# #### Prescription drugs
#
# Products which you can't buy without a prescription and are to treat a confirmed diagnosis or medical condition or to compensate a lack of vital bodily substances. Examples are antibiotics, sedatives, etc. Prescription drugs must be clinically proven to be effective for the diagnosed condition. They must also be recognised by internationally accepted medical guidelines. You can claim for a supply of up to a three months from the prescription date, subject to length of time remaining on the policy.
#
#
# 2. Score: 0.5
#  # How to use your cover
# ## Terms and conditions of your cover
# ### Definitions
# #### Partner
#
# A legal partner or a person you have lived with in a de facto relationship for a continuous period of 12 months.
#
#
# 3. Score: 0.33333334
#  # How to use your cover
# ## Terms and conditions of your cover
# ...

# %%
reranked_dcos = reranker.rerank(query=query, documents=docs, top_n=5)
print("Reranked Documents:")
for idx, (doc) in enumerate(reranked_dcos):
    print(f"{idx + 1}. \n {doc.page_content} \n \n")  # Print first 100 characters
# Out:
# Reranked Documents:
# 1.
#  # How to use your cover
# ## Understanding how your cover works
# ### What are benefit limits?
#
# Your cover may be subject to a maximum plan limit. This is the maximum we will pay in total for all benefits included in the plan per member, per Insurance Year.
# If your plan has a maximum plan limit, it will apply even where:
# - the term 'Full refund' appears next to the benefit.
# - a specific benefit limit applies – this is when the benefit is capped to a specific amount (e.g. £ 2,490 / € 3,000 / US$ 4,050 / CHF 3,900).
# Benefit limits may be provided on a 'per Insurance Year' basis, on a 'per lifetime' basis or on a 'per event' basis (such as per trip, per visit or per pregnancy).
# ---
# In some instances, in addition to the benefit limit, we will only pay a percentage of the costs for the specific benefit (e.g. 80%).
#
#
# 2.
#  # How to use your cover
# ## Understanding how your cover works
# ### What are co-payments?
#
# ...

# %%
# Assuming your variable is named 'results'
first_result = raw_results[0]  # This is the (Document, Score) tuple
doc, score = first_result   # Unpacking the tuple

# Accessing the main content
content = doc.page_content

# Accessing the metadata dictionary
metadata = doc.metadata
provider = metadata.get('insurance_provider')
doc_id = metadata.get('document_id')

print(f"Score: {score}")
print(f"Provider: {provider}")
print(f"Content: {content}")
# Out:
# Score: 0.5
# Provider: cigna_close_care
# Content: # Cigna Close Care™ Policy Rules
# ## SECTION 2: GENERAL EXCLUSIONS
#
# c) a medical practitioner, therapist, hospital, clinic, or facility which, in our reasonable opinion, is either not properly qualified or authorised to provide treatment, or is not competent to provide treatment.
# 2.  Treatment for:
# a) a pre-existing condition; or
# b) any condition or symptoms which result from, or are related to, a pre-existing condition.
# We will not pay for treatment for a pre-existing condition of which the policyholder was (or should reasonably have been) aware at the date cover commenced, and in respect of which we have not expressly agreed to provide cover.
# 3.  Preventative treatment, including but not limited to health screening, routine health checks and vaccinations (unless that treatment is available under one of the options under which a beneficiary has cover). We will pay for preventative surgery when a beneficiary:
# ...

# %%
from src.agents.retriever import RetrieverAgent                                                                                                                
                                                                                                                                                                
agent = RetrieverAgent() 
query= "Under what conditions is a newborn baby insured immediately without a qualifying period or medical underwriting?"                                                                                                                                      
result = agent.invoke(query, "globality_yougenio")

# %%
import textwrap

output = result["answer"]

print(textwrap.fill(output[0]["text"], width=80))
# Out:
# Based on the documents provided, a newborn baby is insured from the moment of
# birth without qualifying periods or medical underwriting under the following
# conditions:  *   **Mother’s Insurance Duration:** The birth mother must have
# been insured under the Globality YouGenio® World plan for at least **six
# consecutive months** prior to the date of birth. *   **Application Timeline:**
# The application for the baby’s insurance must be received within **two months**
# of the birth. *   **Level of Cover:** The insurance cover for the newborn cannot
# be greater or more comprehensive than that of one of the insured parents.  If
# the mother has not been insured for the required six months or the application
# is not received within two months, the insurer will not provide coverage without
# medical underwriting.

# %%
from src.agents.retriever import RetrieverAgent

# %%
agent = ComparerAgent()                                                                                                                                                                                 
result = agent.invoke(                                                                                                                                                                                  
    query="In welke van de onderzochte polissen is dekking in het thuisland (Nederland) volledig inbegrepen bij tijdelijk terugkeerbezoek??",                                                                                                                                                     
    insurance_providers=["goudse_expat_pakket", "oom_wib"],                                                                                                                                                     
)                                                                                                                                                                                                       
print(result["comparison"])       # The final comparison                                                                                                                                                
print(result["provider_results"]) # Individual answers per provider
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 agent = ComparerAgent()
# ----> 2 result = agent.invoke(
#       3     query="In welke van de onderzochte polissen is dekking in het thuisland (Nederland) volledig inbegrepen bij tijdelijk terugkeerbezoek??",
#       4     insurance_providers=["goudse_expat_pakket", "oom_wib"],
#       5 )
#       6 print(result["comparison"])       # The final comparison
#       7 print(result["provider_results"]) # Individual answers per provider
#
# File ~/dev/joho/advies_agent/src/agents/comparer/graphs.py:74, in ComparerAgent.invoke(self, query, insurance_providers, k, top_n)
#      65 def invoke(self, query: str, insurance_providers: list[str], k: int = 15, top_n: int = 5) -> dict:
#      66     """Run the comparer graph.
#      67
#      68     Args:
# ...

# %%
print(result["provider_results"])
# Out:
# [ProviderResult(insurance_provider='goudse_expat_pakket', answer='In de onderzochte polissen is dekking in Nederland bij een tijdelijk terugkeerbezoek volledig (100%) inbegrepen bij de volgende pakketten van het **Goudse Expat Pakket**:\n\n*   **Standard**\n*   **Optimal**\n*   **Excellent**\n\nIn de documenten wordt specifiek vermeld dat voor deze plannen de vergoeding voor dekking tijdens een bezoek aan Nederland 100% bedraagt.'), ProviderResult(insurance_provider='oom_wib', answer='Hoewel de verstrekte documenten geen eenduidig antwoord geven op de vraag of de dekking in Nederland "volledig" is, bevatten ze wel belangrijke informatie over de voorwaarden en beperkingen van de **OOM Living Abroad Insurance** tijdens een tijdelijk verblijf in Nederland:\n\n*   **Wereldwijde dekking voor specifieke onderdelen:** De **SOS-verzekering** en de **OOM Tandartsdekking** zijn altijd wereldwijd geldig. Dit betekent dat deze onderdelen van de polis ook dekking bieden tijdens een tijdelijk verb
# ...
